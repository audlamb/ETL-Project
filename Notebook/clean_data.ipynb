# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
beverage_file = "../Resources/mixed_beverage_gross_receipts.csv"

# %%
beverage_df = pd.read_csv(beverage_file)
beverage_df.head(1)
# Out:
#    Taxpayer Number          Taxpayer Name Taxpayer Address Taxpayer City  \
# 0      17606876674  FROGGIES SALOON, INC.      PO BOX 2961        CONROE
#
#   Taxpayer State  Taxpayer Zip  Taxpayer County  Location Number  \
# 0             TX       77305.0              170                1
#
#      Location Name                Location Address       ...        \
# 0  FROGGIES SALOON  13845 CYPRESS NORTH HOUSTON RD       ...
#
#   Inside/Outside City Limits TABC Permit Number  Responsibility Begin Date  \
# 0                          Y           MB479537                 09/08/2000
#
#    Responsibility End Date Obligation End Date Liquor Receipts Wine Receipts  \
# 0               09/07/2009          12/31/2007           17618           178
#
#   Beer Receipts Cover Charge Receipts  Total Receipts
# 0         13342                     0           31138
#
# [1 rows x 24 columns]

# %%
cols = ["Taxpayer Number", "Taxpayer Name", "Taxpayer City", "Taxpayer State", "Taxpayer Zip", "Taxpayer County", "Location Name", "Location Address", "Liquor Receipts", "Wine Receipts", "Beer Receipts", "Total Receipts"]
beverage_clean = beverage_df[cols]
cols_to_rename = {"Taxpayer Number": "tax_number", 
                  "Taxpayer Name": "tax_name",
                  "Taxpayer City": "tax_city", 
                  "Taxpayer State": "tax_state", 
                  "Taxpayer Zip": "tax_zip", 
                  "Taxpayer County": "tax_county", 
                  "Location Name": "location_name", 
                  "Location Address": "location_address", 
                  "Liquor Receipts": "total_liquor", 
                  "Wine Receipts": "total_wine", 
                  "Beer Receipts": "total_beer",
                  "Total Receipts": "total_all"}



beverage_clean = beverage_clean.rename(columns = cols_to_rename)
beverage_clean = beverage_clean.set_index("tax_number")
beverage_clean.head(10)
# Out:
#                                    tax_name  tax_city tax_state  tax_zip  \
# tax_number
# 17606876674           FROGGIES SALOON, INC.    CONROE        TX  77305.0
# 12016754884                J R POCKETS CLUB    DENTON        TX  76205.0
# 30116266419                      TEXAS ROSE  HUTCHINS        TX  75141.0
# 12622195266              PLOWMAN & WU, INC.  AMARILLO        TX  79106.0
# 13420337860            TRAVIS PROJECT, INC.     KIRBY        TX  78219.0
# 30116276806                PIZZA GETTI CLUB     LAVON        TX  75166.0
# 11342541874              PHM BEVERAGE, INC.    BOSTON        MA   2109.0
# 17514214240      RED LOBSTER OF TEXAS, INC.   ORLANDO        FL  32869.0
# 17521901177             FOOD CATERING, INC.    DALLAS        TX  75219.0
# 17519330587  CHILI'S BEVERAGE COMPANY, INC.    DALLAS        TX  75240.0
#
#              tax_county                       location_name  \
# tax_number
# 17606876674         170                     FROGGIES SALOON
# 12016754884          61                    J R POCKETS CLUB
# 30116266419          57                          TEXAS ROSE
# 12622195266         191  TEXAS FIREHOUSE SPORTS BAR & GRILL
# 13420337860          15                         BOOZEHOUNDS
# 30116276806          43                    PIZZA GETTI CLUB
# 11342541874           0                  PHM BEVERAGE, INC.
# 17514214240           0            RED LOBSTER OF TEXAS INC
# 17521901177          57                        FOOD COMPANY
# 17519330587          57                 CHILI'S GRILL & BAR
#
#                            location_address  total_liquor  total_wine  \
# tax_number
# 17606876674  13845 CYPRESS NORTH HOUSTON RD         17618         178
# 12016754884              1127 FORT WORTH DR         20987         193
# 30116266419    4080 N INTERSTATE HIGHWAY 45         12855          42
# 12622195266        3333 S COULTER ST STE D1          5335         483
# 13420337860           8531 PERRIN BEITEL RD         25560         277
# 30116276806               7008 HIGHWAY 78 S          9095         253
# 11342541874                1111 NE LOOP 410          4521        1311
# 17514214240            2702 PARKER DR STE A         14286        3627
# 17521901177               4115 LOMO ALTO DR          9341       47468
# 17519330587           1000 E US HIGHWAY 377         15621        2045
#
#              total_beer  total_all
# tax_number
# 17606876674       13342      31138
# 12016754884       17484      38664
# 30116266419       13517      26414
# 12622195266       15691      21509
# 13420337860       24131      49968
# 30116276806        9666      19014
# 11342541874        3103       8935
# 17514214240        5217      23130
# 17521901177         673      57482
# 17519330587       12706      30372

# %%
beverage_clean.head(10)
# Out:
#                                    tax_name  tax_city tax_state  tax_zip  \
# tax_number
# 17606876674           FROGGIES SALOON, INC.    CONROE        TX  77305.0
# 12016754884                J R POCKETS CLUB    DENTON        TX  76205.0
# 30116266419                      TEXAS ROSE  HUTCHINS        TX  75141.0
# 12622195266              PLOWMAN & WU, INC.  AMARILLO        TX  79106.0
# 13420337860            TRAVIS PROJECT, INC.     KIRBY        TX  78219.0
# 30116276806                PIZZA GETTI CLUB     LAVON        TX  75166.0
# 11342541874              PHM BEVERAGE, INC.    BOSTON        MA   2109.0
# 17514214240      RED LOBSTER OF TEXAS, INC.   ORLANDO        FL  32869.0
# 17521901177             FOOD CATERING, INC.    DALLAS        TX  75219.0
# 17519330587  CHILI'S BEVERAGE COMPANY, INC.    DALLAS        TX  75240.0
#
#              tax_county                       location_name  \
# tax_number
# 17606876674         170                     FROGGIES SALOON
# 12016754884          61                    J R POCKETS CLUB
# 30116266419          57                          TEXAS ROSE
# 12622195266         191  TEXAS FIREHOUSE SPORTS BAR & GRILL
# 13420337860          15                         BOOZEHOUNDS
# 30116276806          43                    PIZZA GETTI CLUB
# 11342541874           0                  PHM BEVERAGE, INC.
# 17514214240           0            RED LOBSTER OF TEXAS INC
# 17521901177          57                        FOOD COMPANY
# 17519330587          57                 CHILI'S GRILL & BAR
#
#                            location_address  total_liquor  total_wine  \
# tax_number
# 17606876674  13845 CYPRESS NORTH HOUSTON RD         17618         178
# 12016754884              1127 FORT WORTH DR         20987         193
# 30116266419    4080 N INTERSTATE HIGHWAY 45         12855          42
# 12622195266        3333 S COULTER ST STE D1          5335         483
# 13420337860           8531 PERRIN BEITEL RD         25560         277
# 30116276806               7008 HIGHWAY 78 S          9095         253
# 11342541874                1111 NE LOOP 410          4521        1311
# 17514214240            2702 PARKER DR STE A         14286        3627
# 17521901177               4115 LOMO ALTO DR          9341       47468
# 17519330587           1000 E US HIGHWAY 377         15621        2045
#
#              total_beer  total_all
# tax_number
# 17606876674       13342      31138
# 12016754884       17484      38664
# 30116266419       13517      26414
# 12622195266       15691      21509
# 13420337860       24131      49968
# 30116276806        9666      19014
# 11342541874        3103       8935
# 17514214240        5217      23130
# 17521901177         673      57482
# 17519330587       12706      30372

# %%
beverage_clean = beverage_clean[tax_zip].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a35941392228> in <module>
# ----> 1 beverage_clean = beverage_clean[tax_zip].astype(int)
#
# NameError: name 'tax_zip' is not defined
